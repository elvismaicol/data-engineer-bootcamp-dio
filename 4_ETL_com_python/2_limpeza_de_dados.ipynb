# %%
import pandas as pd

# %%
path = 'C:/Temp/dio/arquivos/data-engineer/raw/'

# %%
file_ocorrencia = 'ocorrencia.csv'

# %%
df_oc = pd.read_csv(path + file_ocorrencia, sep=';', parse_dates=['ocorrencia_dia'], dayfirst=True)

# %%
df_oc.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0              52242               52242               52242
# 1              45331               45331               45331
# 2              45333               45333               45333
# 3              45401               45401               45401
# 4              45407               45407               45407
#
#    codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 0               52242               52242                INCIDENTE
# 1               45331               45331                 ACIDENTE
# 2               45333               45333                 ACIDENTE
# 3               45401               45401                 ACIDENTE
# 4               45407               45407                 ACIDENTE
#
#   ocorrencia_latitude ocorrencia_longitude ocorrencia_cidade ocorrencia_uf  \
# 0                 NaN                  NaN      PORTO ALEGRE            RS
# ...

# %%
df = df_oc[['codigo_ocorrencia','codigo_ocorrencia2','ocorrencia_classificacao','ocorrencia_cidade','ocorrencia_uf','ocorrencia_aerodromo','ocorrencia_dia','ocorrencia_hora','total_recomendacoes']]

# %%
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              52242               52242                INCIDENTE
# 1              45331               45331                 ACIDENTE
# 2              45333               45333                 ACIDENTE
# 3              45401               45401                 ACIDENTE
# 4              45407               45407                 ACIDENTE
#
#   ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      PORTO ALEGRE            RS                 SBPA     2012-01-05
# 1         GUARULHOS            SP                 SBGR     2012-01-06
# 2            VIAMÃO            RS                 ****     2012-01-06
# 3     SÃO SEBASTIÃO            SP                 ****     2012-01-06
# 4          SÃO SEPÉ            RS                 ****     2012-01-06
#
#   ocorrencia_hora  total_recomendacoes
# 0        20:27:00                    0
# 1        13:44:00                    3
# ...

# %%
df.loc[1, 'ocorrencia_cidade']
# Out:
# 'GUARULHOS'

# %%
# dados da linha 1 até 3
df.loc[1:3]
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 1              45331               45331                 ACIDENTE
# 2              45333               45333                 ACIDENTE
# 3              45401               45401                 ACIDENTE
#
#   ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 1         GUARULHOS            SP                 SBGR     2012-01-06
# 2            VIAMÃO            RS                 ****     2012-01-06
# 3     SÃO SEBASTIÃO            SP                 ****     2012-01-06
#
#   ocorrencia_hora  total_recomendacoes
# 1        13:44:00                    3
# 2        13:00:00                    0
# 3        17:00:00                    0

# %%
# dados das linhas 10 e 40
df.loc[[10, 40]]
# Out:
#     codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 10              45332               45332                 ACIDENTE
# 40              45415               45415                 ACIDENTE
#
#    ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 10            VIAMÃO            RS                 ****     2012-01-09
# 40    RIO DE JANEIRO            RJ                 ****     2012-01-30
#
#    ocorrencia_hora  total_recomendacoes
# 10        13:30:00                    0
# 40        13:55:00                    0

# %%
# todas as linhas de uma coluna
df.loc[:, 'ocorrencia_cidade']
# Out:
# 0        PORTO ALEGRE
# 1           GUARULHOS
# 2              VIAMÃO
# 3       SÃO SEBASTIÃO
# 4            SÃO SEPÉ
#             ...
# 5162            JATAÍ
# 5163          MARACAÍ
# 5164    NOVO HAMBURGO
# 5165         CURITIBA
# 5166        PETROLINA
# Name: ocorrencia_cidade, Length: 5167, dtype: object

# %%
# Verificando se na coluna só há dados unicos(não duplicados)
df.codigo_ocorrencia.is_unique
# Out:
# True

# %%
df.ocorrencia_uf.is_unique
# Out:
# False

# %%
# definindo uma coluna como indice
df.set_index('codigo_ocorrencia')
# Out:
#                    codigo_ocorrencia2 ocorrencia_classificacao  \
# codigo_ocorrencia
# 52242                           52242                INCIDENTE
# 45331                           45331                 ACIDENTE
# 45333                           45333                 ACIDENTE
# 45401                           45401                 ACIDENTE
# 45407                           45407                 ACIDENTE
# ...                               ...                      ...
# 80458                           80458                 ACIDENTE
# 80452                           80452                 ACIDENTE
# 80457                           80457          INCIDENTE GRAVE
# 80460                           80460                INCIDENTE
# 80467                           80467                INCIDENTE
#
#                   ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo  \
# codigo_ocorrencia
# 52242                  PORTO ALEGRE            RS                 SBPA
# ...

# %%
#  inplace=True -> esse parametro autera no DataFrame
df.set_index('codigo_ocorrencia', inplace=True)

# %%
df.loc[45331]
# Out:
# codigo_ocorrencia2                        45331
# ocorrencia_classificacao               ACIDENTE
# ocorrencia_cidade                     GUARULHOS
# ocorrencia_uf                                SP
# ocorrencia_aerodromo                       SBGR
# ocorrencia_dia              2012-01-06 00:00:00
# ocorrencia_hora                        13:44:00
# total_recomendacoes                           3
# Name: 45331, dtype: object

# %%
# retornar oa indice original
df.reset_index(drop=True, inplace=True)

# %%
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              52242               52242                INCIDENTE
# 1              45331               45331                 ACIDENTE
# 2              45333               45333                 ACIDENTE
# 3              45401               45401                 ACIDENTE
# 4              45407               45407                 ACIDENTE
#
#   ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      PORTO ALEGRE            RS                 SBPA     2012-01-05
# 1         GUARULHOS            SP                 SBGR     2012-01-06
# 2            VIAMÃO            RS                 ****     2012-01-06
# 3     SÃO SEBASTIÃO            SP                 ****     2012-01-06
# 4          SÃO SEPÉ            RS                 ****     2012-01-06
#
#   ocorrencia_hora  total_recomendacoes
# 0        20:27:00                    0
# 1        13:44:00                    3
# ...

# %%
df.loc[2:2]
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 2              45333               45333                 ACIDENTE
#
#   ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 2            VIAMÃO            RS                          2012-01-06
#
#   ocorrencia_hora  total_recomendacoes
# 2        13:00:00                    0

# %%
df2 = df.copy()

# %%
df.loc[2,'ocorrencia_aerodromo'] = ""
# Out:
# C:\Users\Elvis\anaconda3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
df.loc[2,'ocorrencia_aerodromo']
# Out:
# ''

# %%
df
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 52242               52242                INCIDENTE
# 1                 45331               45331                 ACIDENTE
# 2                 45333               45333                 ACIDENTE
# 3                 45401               45401                 ACIDENTE
# 4                 45407               45407                 ACIDENTE
# ...                 ...                 ...                      ...
# 5162              80458               80458                 ACIDENTE
# 5163              80452               80452                 ACIDENTE
# 5164              80457               80457          INCIDENTE GRAVE
# 5165              80460               80460                INCIDENTE
# 5166              80467               80467                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
df.loc[1:] = 20

# %%
df.loc[:, 'total_recomendacoes'] = 10

# %%
df.total_recomendacoes
# Out:
# 0       10
# 1       10
# 2       10
# 3       10
# 4       10
#         ..
# 5162    10
# 5163    10
# 5164    10
# 5165    10
# 5166    10
# Name: total_recomendacoes, Length: 5167, dtype: int64

# %%
df["ocorrencia_uf_bkp"] = df.ocorrencia_uf
# Out:
# <ipython-input-151-5a8510d772cd>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ocorrencia_uf_bkp"] = df.ocorrencia_uf

# %%
df
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 52242               52242                INCIDENTE
# 1                 45331               45331                 ACIDENTE
# 2                 45333               45333                 ACIDENTE
# 3                 45401               45401                 ACIDENTE
# 4                 45407               45407                 ACIDENTE
# ...                 ...                 ...                      ...
# 5162              80458               80458                 ACIDENTE
# 5163              80452               80452                 ACIDENTE
# 5164              80457               80457          INCIDENTE GRAVE
# 5165              80460               80460                INCIDENTE
# 5166              80467               80467                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
# Alterando os dados de uma coluna usando um filtro em outra coluna como parametro
df.loc[df.ocorrencia_uf == 'SP', ['ocorrencia_classificacao']] = 'GRAVE'
# Out:
# C:\Users\Elvis\anaconda3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
df
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 52242               52242                INCIDENTE
# 1                 45331               45331                 ACIDENTE
# 2                 45333               45333                 ACIDENTE
# 3                 45401               45401                 ACIDENTE
# 4                 45407               45407                 ACIDENTE
# ...                 ...                 ...                      ...
# 5162              80458               80458                 ACIDENTE
# 5163              80452               80452                 ACIDENTE
# 5164              80457               80457          INCIDENTE GRAVE
# 5165              80460               80460                INCIDENTE
# 5166              80467               80467                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
ocorrencia_uf
**
ocorrencia_aerodromo
****
*****
####
###!
ocorrencia_hora
NULL

# %%
df.loc[df.ocorrencia_uf == '**', ['ocorrencia_uf']]
# Out:
#      ocorrencia_uf
# 1099            **
# 4728            **

# %%
df.loc[df.ocorrencia_uf == '**', ['ocorrencia_uf']] = pd.NA
# Out:
# C:\Users\Elvis\anaconda3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
df.loc[1099, ['ocorrencia_uf']]
# Out:
# ocorrencia_uf    <NA>
# Name: 1099, dtype: object

# %%
df.replace(['**', '****', '*****', '####', '###!', 'NULL'], pd.NA, inplace=True)
# Out:
# C:\Users\Elvis\anaconda3\lib\site-packages\pandas\core\frame.py:4524: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().replace(

# %%
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              52242               52242                INCIDENTE
# 1              45331               45331                 ACIDENTE
# 2              45333               45333                 ACIDENTE
# 3              45401               45401                 ACIDENTE
# 4              45407               45407                 ACIDENTE
#
#   ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      PORTO ALEGRE            RS                 SBPA     2012-01-05
# 1         GUARULHOS            SP                 SBGR     2012-01-06
# 2            VIAMÃO            RS                 <NA>     2012-01-06
# 3     SÃO SEBASTIÃO            SP                 <NA>     2012-01-06
# 4          SÃO SEPÉ            RS                 <NA>     2012-01-06
#
#   ocorrencia_hora  total_recomendacoes
# 0        20:27:00                    0
# 1        13:44:00                    3
# ...

# %%
df.tail()
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 5162              80458               80458                 ACIDENTE
# 5163              80452               80452                 ACIDENTE
# 5164              80457               80457          INCIDENTE GRAVE
# 5165              80460               80460                INCIDENTE
# 5166              80467               80467                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 5162             JATAÍ            GO                 <NA>     2021-12-30
# 5163           MARACAÍ            SP                 <NA>     2021-12-31
# 5164     NOVO HAMBURGO            RS                 SSNH     2021-12-31
# 5165          CURITIBA            PR                 SBBI     2021-12-31
# 5166         PETROLINA            PE                 SBPL     2021-12-31
#
#      ocorrencia_hora  total_recomendacoes
# 5162        20:30:00                    0
# ...

# %%
# mostra os dados não informados no DF
df.isna()
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2  ocorrencia_classificacao  \
# 0                 False               False                     False
# 1                 False               False                     False
# 2                 False               False                     False
# 3                 False               False                     False
# 4                 False               False                     False
# ...                 ...                 ...                       ...
# 5162              False               False                     False
# 5163              False               False                     False
# 5164              False               False                     False
# 5165              False               False                     False
# 5166              False               False                     False
#
#       ocorrencia_cidade  ocorrencia_uf  ocorrencia_aerodromo  ocorrencia_dia  \
# ...

# %%
# mostra a quantidade de dados NA por coluna
df.isna().sum()
# Out:
# codigo_ocorrencia              0
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  2
# ocorrencia_aerodromo        1905
# ocorrencia_dia                 0
# ocorrencia_hora                1
# total_recomendacoes            0
# dtype: int64

# %%
# também mostra os dados não informados no DF
df.isnull()
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2  ocorrencia_classificacao  \
# 0                 False               False                     False
# 1                 False               False                     False
# 2                 False               False                     False
# 3                 False               False                     False
# 4                 False               False                     False
# ...                 ...                 ...                       ...
# 5162              False               False                     False
# 5163              False               False                     False
# 5164              False               False                     False
# 5165              False               False                     False
# 5166              False               False                     False
#
#       ocorrencia_cidade  ocorrencia_uf  ocorrencia_aerodromo  ocorrencia_dia  \
# ...

# %%
# substiutuindo os NAs por outro dado (ex.: 10)
df.fillna(10 , inplace=True)
# Out:
# C:\Users\Elvis\anaconda3\lib\site-packages\pandas\core\frame.py:4462: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %%
df.isna().sum()
# Out:
# codigo_ocorrencia           0
# codigo_ocorrencia2          0
# ocorrencia_classificacao    0
# ocorrencia_cidade           0
# ocorrencia_uf               0
# ocorrencia_aerodromo        0
# ocorrencia_dia              0
# ocorrencia_hora             0
# total_recomendacoes         0
# dtype: int64

# %%
df.loc[1099, ['ocorrencia_uf']]
# Out:
# ocorrencia_uf    10
# Name: 1099, dtype: object

# %%
df.replace([10], pd.NA, inplace=True)
# Out:
# C:\Users\Elvis\anaconda3\lib\site-packages\pandas\core\frame.py:4524: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().replace(

# %%
df.isna().sum()
# Out:
# codigo_ocorrencia              0
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  2
# ocorrencia_aerodromo        1905
# ocorrencia_dia                 0
# ocorrencia_hora                1
# total_recomendacoes            0
# dtype: int64

# %%
df.fillna(value={'total_recomendacoes': 10}, inplace=True)
# Out:
# C:\Users\Elvis\anaconda3\lib\site-packages\pandas\core\series.py:4463: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %%
df.isna().sum()
# Out:
# codigo_ocorrencia              0
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  2
# ocorrencia_aerodromo        1905
# ocorrencia_dia                 0
# ocorrencia_hora                1
# total_recomendacoes            0
# dtype: int64

# %%
# incluindo uma coluna do DF como backup de outra
df['total_recomendacoes_bkp'] = df.total_recomendacoes
# Out:
# <ipython-input-186-1d46532c02fa>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['total_recomendacoes_bkp'] = df.total_recomendacoes

# %%
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              52242               52242                INCIDENTE
# 1              45331               45331                 ACIDENTE
# 2              45333               45333                 ACIDENTE
# 3              45401               45401                 ACIDENTE
# 4              45407               45407                 ACIDENTE
#
#   ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      PORTO ALEGRE            RS                 SBPA     2012-01-05
# 1         GUARULHOS            SP                 SBGR     2012-01-06
# 2            VIAMÃO            RS                 <NA>     2012-01-06
# 3     SÃO SEBASTIÃO            SP                 <NA>     2012-01-06
# 4          SÃO SEPÉ            RS                 <NA>     2012-01-06
#
#   ocorrencia_hora  total_recomendacoes  total_recomendacoes_bkp
# 0        20:27:00                    0                        0
# ...

# %%
# Excluindo uma coluna do DF
# axis=1 -> eixo, por default é 0
df.drop(['total_recomendacoes_bkp'], axis=1, inplace=True)
# Out:
# C:\Users\Elvis\anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              52242               52242                INCIDENTE
# 1              45331               45331                 ACIDENTE
# 2              45333               45333                 ACIDENTE
# 3              45401               45401                 ACIDENTE
# 4              45407               45407                 ACIDENTE
#
#   ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      PORTO ALEGRE            RS                 SBPA     2012-01-05
# 1         GUARULHOS            SP                 SBGR     2012-01-06
# 2            VIAMÃO            RS                 <NA>     2012-01-06
# 3     SÃO SEBASTIÃO            SP                 <NA>     2012-01-06
# 4          SÃO SEPÉ            RS                 <NA>     2012-01-06
#
#   ocorrencia_hora  total_recomendacoes
# 0        20:27:00                    0
# 1        13:44:00                    3
# ...

# %%
df.count()
# Out:
# codigo_ocorrencia           5167
# codigo_ocorrencia2          5167
# ocorrencia_classificacao    5167
# ocorrencia_cidade           5167
# ocorrencia_uf               5165
# ocorrencia_aerodromo        3262
# ocorrencia_dia              5167
# ocorrencia_hora             5166
# total_recomendacoes         5167
# dtype: int64

# %%
# Exclui a linha qua tiver um NA
df.dropna()
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 52242               52242                INCIDENTE
# 1                 45331               45331                 ACIDENTE
# 6                 50713               50713          INCIDENTE GRAVE
# 7                 45334               45334                INCIDENTE
# 9                 52244               52244                INCIDENTE
# ...                 ...                 ...                      ...
# 5160              80451               80451                INCIDENTE
# 5161              80456               80456                INCIDENTE
# 5164              80457               80457          INCIDENTE GRAVE
# 5165              80460               80460                INCIDENTE
# 5166              80467               80467                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
df.dropna().count()
# Out:
# codigo_ocorrencia           3262
# codigo_ocorrencia2          3262
# ocorrencia_classificacao    3262
# ocorrencia_cidade           3262
# ocorrencia_uf               3262
# ocorrencia_aerodromo        3262
# ocorrencia_dia              3262
# ocorrencia_hora             3262
# total_recomendacoes         3262
# dtype: int64

# %%
# Excluindo NA considerando apenas uma coluna
df.dropna(subset=['ocorrencia_uf'])
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 52242               52242                INCIDENTE
# 1                 45331               45331                 ACIDENTE
# 2                 45333               45333                 ACIDENTE
# 3                 45401               45401                 ACIDENTE
# 4                 45407               45407                 ACIDENTE
# ...                 ...                 ...                      ...
# 5162              80458               80458                 ACIDENTE
# 5163              80452               80452                 ACIDENTE
# 5164              80457               80457          INCIDENTE GRAVE
# 5165              80460               80460                INCIDENTE
# 5166              80467               80467                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
df.count()
# Out:
# codigo_ocorrencia           5168
# codigo_ocorrencia2          5168
# ocorrencia_classificacao    5168
# ocorrencia_cidade           5168
# ocorrencia_uf               5168
# ocorrencia_aerodromo        5168
# ocorrencia_dia              5168
# ocorrencia_hora             5167
# total_recomendacoes         5168
# dtype: int64

# %%
# Excluindo linhas duplicadas do DF
df.drop_duplicates()
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 52242               52242                INCIDENTE
# 1                 45331               45331                 ACIDENTE
# 2                 45333               45333                 ACIDENTE
# 3                 45401               45401                 ACIDENTE
# 4                 45407               45407                 ACIDENTE
# ...                 ...                 ...                      ...
# 5162              80458               80458                 ACIDENTE
# 5163              80452               80452                 ACIDENTE
# 5164              80457               80457          INCIDENTE GRAVE
# 5165              80460               80460                INCIDENTE
# 5166              80467               80467                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
df.drop_duplicates(inplace=True)
# Out:
# <ipython-input-213-16cdb8520be8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop_duplicates(inplace=True)

# %%
df.count()
# Out:
# codigo_ocorrencia           5167
# codigo_ocorrencia2          5167
# ocorrencia_classificacao    5167
# ocorrencia_cidade           5167
# ocorrencia_uf               5167
# ocorrencia_aerodromo        5167
# ocorrencia_dia              5167
# ocorrencia_hora             5166
# total_recomendacoes         5167
# dtype: int64
