# %% [markdown]
# ### 1ª ETAPA - EXTRAÇÃO DE DADOS

# %%
import pandas as pd
import pandera as pa

# %%
path = 'C:/Temp/dio/arquivos/data-engineer/raw/'

# %%
file_ocorrencia = 'ocorrencia.csv'

# %%
df_oc = pd.read_csv(path + file_ocorrencia, sep=';', parse_dates=['ocorrencia_dia'], dayfirst=True)

# %% [markdown]
# parse_dates['coluna'] -> converte a coluna para o tipo data
#
# dayfirst=True -> identifica q o 1º valor é dia

# %%
df_oc.head(10)
# Out:
#    codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0              52242               52242               52242
# 1              45331               45331               45331
# 2              45333               45333               45333
# 3              45401               45401               45401
# 4              45407               45407               45407
# 5              52243               52243               52243
# 6              50713               50713               50713
# 7              45334               45334               45334
# 8              45391               45391               45391
# 9              52244               52244               52244
#
#    codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 0               52242               52242                INCIDENTE
# 1               45331               45331                 ACIDENTE
# 2               45333               45333                 ACIDENTE
# ...

# %%
df_oc.columns
# Out:
# Index(['codigo_ocorrencia', 'codigo_ocorrencia1', 'codigo_ocorrencia2',
#        'codigo_ocorrencia3', 'codigo_ocorrencia4', 'ocorrencia_classificacao',
#        'ocorrencia_latitude', 'ocorrencia_longitude', 'ocorrencia_cidade',
#        'ocorrencia_uf', 'ocorrencia_pais', 'ocorrencia_aerodromo',
#        'ocorrencia_dia', 'ocorrencia_hora', 'investigacao_aeronave_liberada',
#        'investigacao_status', 'divulgacao_relatorio_numero',
#        'divulgacao_relatorio_publicado', 'divulgacao_dia_publicacao',
#        'total_recomendacoes', 'total_aeronaves_envolvidas',
#        'ocorrencia_saida_pista'],
#       dtype='object')

# %%
df = df_oc[['codigo_ocorrencia','codigo_ocorrencia2','ocorrencia_classificacao','ocorrencia_cidade','ocorrencia_uf','ocorrencia_aerodromo','ocorrencia_dia','ocorrencia_hora','total_recomendacoes']]

# %%
df.head(10)
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              52242               52242                INCIDENTE
# 1              45331               45331                 ACIDENTE
# 2              45333               45333                 ACIDENTE
# 3              45401               45401                 ACIDENTE
# 4              45407               45407                 ACIDENTE
# 5              52243               52243                INCIDENTE
# 6              50713               50713          INCIDENTE GRAVE
# 7              45334               45334                INCIDENTE
# 8              45391               45391                 ACIDENTE
# 9              52244               52244                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0           PORTO ALEGRE            RS                 SBPA     2012-01-05
# 1              GUARULHOS            SP                 SBGR     2012-01-06
# ...

# %%
df.columns
# Out:
# Index(['codigo_ocorrencia', 'codigo_ocorrencia2', 'ocorrencia_classificacao',
#        'ocorrencia_cidade', 'ocorrencia_uf', 'ocorrencia_aerodromo',
#        'ocorrencia_dia', 'ocorrencia_hora', 'total_recomendacoes'],
#       dtype='object')

# %%
df.dtypes
# Out:
# codigo_ocorrencia                    int64
# codigo_ocorrencia2                   int64
# ocorrencia_classificacao            object
# ocorrencia_cidade                   object
# ocorrencia_uf                       object
# ocorrencia_aerodromo                object
# ocorrencia_dia              datetime64[ns]
# ocorrencia_hora                     object
# total_recomendacoes                  int64
# dtype: object

# %%
df.head(10)
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              52242               52242                INCIDENTE
# 1              45331               45331                 ACIDENTE
# 2              45333               45333                 ACIDENTE
# 3              45401               45401                 ACIDENTE
# 4              45407               45407                 ACIDENTE
# 5              52243               52243                INCIDENTE
# 6              50713               50713          INCIDENTE GRAVE
# 7              45334               45334                INCIDENTE
# 8              45391               45391                 ACIDENTE
# 9              52244               52244                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0           PORTO ALEGRE            RS                 SBPA     2012-01-05
# 1              GUARULHOS            SP                 SBGR     2012-01-06
# ...

# %%
# últimas dados
df.tail(10)
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 5157              80453               80453                INCIDENTE
# 5158              80454               80454          INCIDENTE GRAVE
# 5159              80455               80455          INCIDENTE GRAVE
# 5160              80451               80451                INCIDENTE
# 5161              80456               80456                INCIDENTE
# 5162              80458               80458                 ACIDENTE
# 5163              80452               80452                 ACIDENTE
# 5164              80457               80457          INCIDENTE GRAVE
# 5165              80460               80460                INCIDENTE
# 5166              80467               80467                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 5157          CAMPINAS            SP                 SBKP     2021-12-29
# ...

# %%
df.ocorrencia_dia.dt.month
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 5162    12
# 5163    12
# 5164    12
# 5165    12
# 5166    12
# Name: ocorrencia_dia, Length: 5167, dtype: int64

# %%
df.dtypes
# Out:
# codigo_ocorrencia                    int64
# codigo_ocorrencia2                   int64
# ocorrencia_classificacao            object
# ocorrencia_cidade                   object
# ocorrencia_uf                       object
# ocorrencia_aerodromo                object
# ocorrencia_dia              datetime64[ns]
# ocorrencia_hora                     object
# total_recomendacoes                  int64
# dtype: object

# %% [markdown]
# #### Validando dados com o pandera

# %%
schema = pa.DataFrameSchema(
    columns = {
        "codigo_ocorrencia":pa.Column(pa.Int)
    }
)

# %%
schema.validate(df)
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 52242               52242                INCIDENTE
# 1                 45331               45331                 ACIDENTE
# 2                 45333               45333                 ACIDENTE
# 3                 45401               45401                 ACIDENTE
# 4                 45407               45407                 ACIDENTE
# ...                 ...                 ...                      ...
# 5162              80458               80458                 ACIDENTE
# 5163              80452               80452                 ACIDENTE
# 5164              80457               80457          INCIDENTE GRAVE
# 5165              80460               80460                INCIDENTE
# 5166              80467               80467                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %% [markdown]
# ##### Exemplo com erro
# schema = pa.DataFrameSchema(
#     columns = {
#         "codigo_ocorrencia":pa.Column(pa.DateTime)
#     }
# )

# %%
schema = pa.DataFrameSchema(
    columns = {
        "col_ficticia_codigo" : pa.Column(pa.Int, required=False),
        "codigo_ocorrencia": pa.Column(pa.Int),
        "codigo_ocorrencia2": pa.Column(pa.Int),
        "ocorrencia_classificacao": pa.Column(pa.String),
        "ocorrencia_cidade": pa.Column(pa.String), 
        "ocorrencia_uf": pa.Column(pa.String, pa.Check.str_length(2,2)),
        "ocorrencia_aerodromo": pa.Column(pa.String), 
        "ocorrencia_dia": pa.Column(pa.DateTime),
        "ocorrencia_hora": pa.Column(pa.String, pa.Check.str_matches(r'^([0-1]?[0-9]|[2][0-3]):([0-5][0-9])(:[0-5][0-9])?$'), nullable=True),
        "total_recomendacoes": pa.Column(pa.Int)
    }
)

# %% [markdown]
# ##### pa.Check.str_matches() -> define um formato para validar a hora, usando expressão regular
# ##### pa.Check.str_length(min,max) -> checa se o tamanho da string esta dentro dos limites
# ##### required=False -> validada se a coluna existe no DF, se estivar "False" não vai gerar erro se a coluna não existir

# %%
schema.validate(df)
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 52242               52242                INCIDENTE
# 1                 45331               45331                 ACIDENTE
# 2                 45333               45333                 ACIDENTE
# 3                 45401               45401                 ACIDENTE
# 4                 45407               45407                 ACIDENTE
# ...                 ...                 ...                      ...
# 5162              80458               80458                 ACIDENTE
# 5163              80452               80452                 ACIDENTE
# 5164              80457               80457          INCIDENTE GRAVE
# 5165              80460               80460                INCIDENTE
# 5166              80467               80467                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...
